# %%
import pandas as pd

df = pd.read_csv("COCO_test_sentences.csv")

# %%
#drop rows where the sentences in 'raw' column have more than 10 words
df = df[df['raw'].str.split().str.len() <= 8]

# %%
df = df.sort_values(['imgid','sentid'],ascending=[True,True])

# %%
df_reduced = {
    "imgid":[],
    "sentid":[],
    "cocoid":[],
    "raw":[]
}

imgid_done = set()

for i,row in df.iterrows():
  if row["imgid"] not in imgid_done:
    imgid_done.add(row["imgid"])
    df_reduced["imgid"].append(row["imgid"])
    df_reduced["sentid"].append(row["sentid"])
    df_reduced["cocoid"].append(row["cocoid"])
    df_reduced["raw"].append(row["raw"])


df = pd.DataFrame(df_reduced)

# %%
import numpy as np
len(df), np.mean(df['raw'].str.split().str.len())
# Out:
# (2948, 7.945386702849389)

# %%
from transformers import pipeline

classifier = pipeline("fill-mask")
# Out:
# No model was supplied, defaulted to distilroberta-base and revision ec58a5b (https://huggingface.co/distilroberta-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Some weights of the model checkpoint at distilroberta-base were not used when initializing RobertaForMaskedLM: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
classifier("A <mask> in a machine.")
# Out:
# [{'score': 0.1332135647535324,
#   'token': 37204,
#   'token_str': ' cog',
#   'sequence': 'A cog in a machine.'},
#  {'score': 0.032206032425165176,
#   'token': 19012,
#   'token_str': ' needle',
#   'sequence': 'A needle in a machine.'},
#  {'score': 0.022915644571185112,
#   'token': 6793,
#   'token_str': ' virus',
#   'sequence': 'A virus in a machine.'},
#  {'score': 0.018956581130623817,
#   'token': 4683,
#   'token_str': ' hole',
#   'sequence': 'A hole in a machine.'},
#  {'score': 0.014165378175675869,
#   'token': 14368,
#   'token_str': ' dent',
#   'sequence': 'A dent in a machine.'}]

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification, TokenClassificationPipeline

model_name = "QCRI/bert-base-multilingual-cased-pos-english"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForTokenClassification.from_pretrained(model_name)
# Out:
# Some weights of the model checkpoint at QCRI/bert-base-multilingual-cased-pos-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
pipeline = TokenClassificationPipeline(model=model, tokenizer=tokenizer)
outputs = pipeline(["A man with a red helmet on a small moped on a dirt road.","A man with a red helmet on a small moped on a dirt road."])
print(outputs)
# Out:
# [[{'entity': 'DT', 'score': 0.99982494, 'index': 1, 'word': 'A', 'start': 0, 'end': 1}, {'entity': 'NN', 'score': 0.99958414, 'index': 2, 'word': 'man', 'start': 2, 'end': 5}, {'entity': 'IN', 'score': 0.9995628, 'index': 3, 'word': 'with', 'start': 6, 'end': 10}, {'entity': 'DT', 'score': 0.9998672, 'index': 4, 'word': 'a', 'start': 11, 'end': 12}, {'entity': 'JJ', 'score': 0.99914205, 'index': 5, 'word': 'red', 'start': 13, 'end': 16}, {'entity': 'NN', 'score': 0.99970347, 'index': 6, 'word': 'hel', 'start': 17, 'end': 20}, {'entity': 'NN', 'score': 0.9995078, 'index': 7, 'word': '##met', 'start': 20, 'end': 23}, {'entity': 'IN', 'score': 0.9998085, 'index': 8, 'word': 'on', 'start': 24, 'end': 26}, {'entity': 'DT', 'score': 0.999866, 'index': 9, 'word': 'a', 'start': 27, 'end': 28}, {'entity': 'JJ', 'score': 0.9992562, 'index': 10, 'word': 'small', 'start': 29, 'end': 34}, {'entity': 'NN', 'score': 0.75575167, 'index': 11, 'word': 'mo', 'start': 35, 'end': 37}, {'entity': 'VBD', 'score': 0.42388046, 'index': 12, 'word': '##ped', 'start': 37, 'end': 40}, {'entity': 'IN', 'score': 0.9998073, 'index': 13, 'word': 'on', 'start': 41, 'end': 43}, {'entity': 'DT', 'score': 0.9998658, 'index': 14, 'word': 'a', 'start': 44, 'end': 45}, {'entity': 'NN', 'score': 0.99610883, 'index': 15, 'word': 'dir', 'start': 46, 'end': 49}, {'entity': 'NN', 'score': 0.98960835, 'index': 16, 'word': '##t', 'start': 49, 'end': 50}, {'entity': 'NN', 'score': 0.9997737, 'index': 17, 'word': 'road', 'start': 51, 'end': 55}, {'entity': '.', 'score': 0.999918, 'index': 18, 'word': '.', 'start': 55, 'end': 56}], [{'entity': 'DT', 'score': 0.99982494, 'index': 1, 'word': 'A', 'start': 0, 'end': 1}, {'entity': 'NN', 'score': 0.99958414, 'index': 2, 'word': 'man', 'start': 2, 'end': 5}, {'entity': 'IN', 'score': 0.9995628, 'index': 3, 'word': 'with', 'start': 6, 'end': 10}, {'entity': 'DT', 'score': 0.9998672, 'index': 4, 'word': 'a', 'start': 11, 'end': 12}, {'entity': 'JJ', 'score': 0.99914205, 'index': 5, 'word': 'red', 'start': 13, 'end': 16}, {'entity': 'NN', 'score': 0.99970347, 'index': 6, 'word': 'hel', 'start': 17, 'end': 20}, {'entity': 'NN', 'score': 0.9995078, 'index': 7, 'word': '##met', 'start': 20, 'end': 23}, {'entity': 'IN', 'score': 0.9998085, 'index': 8, 'word': 'on', 'start': 24, 'end': 26}, {'entity': 'DT', 'score': 0.999866, 'index': 9, 'word': 'a', 'start': 27, 'end': 28}, {'entity': 'JJ', 'score': 0.9992562, 'index': 10, 'word': 'small', 'start': 29, 'end': 34}, {'entity': 'NN', 'score': 0.75575167, 'index': 11, 'word': 'mo', 'start': 35, 'end': 37}, {'entity': 'VBD', 'score': 0.42388046, 'index': 12, 'word': '##ped', 'start': 37, 'end': 40}, {'entity': 'IN', 'score': 0.9998073, 'index': 13, 'word': 'on', 'start': 41, 'end': 43}, {'entity': 'DT', 'score': 0.9998658, 'index': 14, 'word': 'a', 'start': 44, 'end': 45}, {'entity': 'NN', 'score': 0.99610883, 'index': 15, 'word': 'dir', 'start': 46, 'end': 49}, {'entity': 'NN', 'score': 0.98960835, 'index': 16, 'word': '##t', 'start': 49, 'end': 50}, {'entity': 'NN', 'score': 0.9997737, 'index': 17, 'word': 'road', 'start': 51, 'end': 55}, {'entity': '.', 'score': 0.999918, 'index': 18, 'word': '.', 'start': 55, 'end': 56}]]

# %%
import datasets
ds = datasets.Dataset.from_pandas(df)

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.corpus import wordnet

def is_noun(word):
    synsets = wordnet.synsets(word.lower().strip())
    return any([synset.pos() == wordnet.NOUN for synset in synsets])


def are_synonyms(word1, word2):

    synsets1 = wordnet.synsets(word1.lower().strip())
    synsets2 = wordnet.synsets(word2.lower().strip())
    return any(set(synset1.lemma_names()).intersection(synset2.lemma_names()) for synset1 in synsets1 for synset2 in synsets2)

def is_subtype(word_subtype, word_type):
    synsets_subtype = wordnet.synsets(word_subtype.lower().strip())
    synsets_type = wordnet.synsets(word_type.lower().strip())

    for syn_subtype in synsets_subtype:
        hypernyms = set([i for i in syn_subtype.closure(lambda s:s.hypernyms())])

        for syn_type in synsets_type:
            if syn_type in hypernyms:
                return True

    return False


word1 = "happy"
word2 = "joyful"

print(are_synonyms(word1, word2))
# Out:
# False

# %%
from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")

df_new = {
    "imgid":[],
    "sentid":[],
    "cocoid":[],
    "base_sentence":[],
    "new_sentence":[]
}

skip_words = set([
    "man",
    "woman",
    "boy",
    "girl",
    "person",
    "people",
    "group",
    "pair",
    "couple",
    "team",
    "someone",
    "individual",
    "somebody",
    "child",
    "baby",
    "squad",
    "grouping",
    "bunch",
    "crowd",
    "adult",
    "guy",
    "image",
    "photo",
    "picture",
    "photograph",
    "scene",
    "herd",
    "flock",
    "pair"
])


for data in tqdm(ds):

  base_sentence = data["raw"]
  POS_result = pipeline(base_sentence)
  successful_NN = False

  for i,result in enumerate(POS_result):
    if successful_NN:
      break
    if result["entity"]=="NN" and result["word"].lower().strip() not in skip_words and not result["word"].startswith("##"):
      candidate_word = result["word"]

      k=1
      while True:
        if i+k >= len(POS_result):
          break
        if not POS_result[i+k]["word"].startswith("##"):
          break
        else:
          candidate_word+=POS_result[i+k]["word"][len("##"):]
          k+=1

      #skip if the candidate word is in the base sentence more than once
      if base_sentence.count(candidate_word) > 1:
        continue

      if len(candidate_word) < 3:
        continue

      if not is_noun(candidate_word):
        continue

      masked_sentence = base_sentence.replace(candidate_word, "<mask>")

      fill_mask_result = classifier(masked_sentence)

      new_word = None

      for result in fill_mask_result:
        new_word = result["token_str"]

        if len(new_word) < 3:
          new_word = None
          break

        if not is_noun(new_word):
          new_word = None
          continue

        if new_word in base_sentence:
          new_word = None
          continue

        if are_synonyms(new_word, candidate_word):
          new_word = None
          continue

        if is_subtype(new_word, candidate_word) or is_subtype(candidate_word, new_word):
          new_word = None
          continue
      
      if new_word is None:
        continue

      replaced_sentence = fill_mask_result[0]["sequence"]




      if base_sentence != replaced_sentence:
        df_new["imgid"].append(data["imgid"])
        df_new["sentid"].append( data["sentid"])
        df_new["cocoid"].append( data["cocoid"])
        df_new["base_sentence"].append(base_sentence)
        df_new["new_sentence"].append( replaced_sentence)

      successful_NN = True
# Out:
# 100%|██████████| 2948/2948 [06:14<00:00,  7.87it/s]

# %%
df2 = pd.DataFrame(df_new)
len(df2)
# Out:
# 2093

# %%
#sample 500 with seed 42

df2 = df2.sample(500,random_state=42)

# %%
df2.to_csv("COCO_test_pairs.csv", index=False)

df2 = pd.read_csv("COCO_test_pairs.csv")

# %%
with open("COCO_test_pairs_for_ADV.txt","w") as f:
    for i, row in df2.iterrows():
        print("""("{}", "{}"),""".format(row["base_sentence"], row["new_sentence"]))
        print("""("{}", "{}"),""".format(row["new_sentence"], row["base_sentence"]))

        f.write("""("{}", "{}"),\n""".format(row["base_sentence"], row["new_sentence"]))
        f.write("""("{}", "{}"),\n""".format(row["new_sentence"], row["base_sentence"]))

        if (i+1) % 5 == 0:
            print(i)
            f.write("{}\n".format(i))
# Out:
# ("An ornate vintage clock with several faces. ", "An ornate quartz clock with several faces. "),
# ("An ornate quartz clock with several faces. ", "An ornate vintage clock with several faces. "),
# ("A elephant that is standing in the dirt.", "A tree that is standing in the dirt."),
# ("A tree that is standing in the dirt.", "A elephant that is standing in the dirt."),
# ("A clock mounted with chains outside a building", "A protester mounted with chains outside a building"),
# ("A protester mounted with chains outside a building", "A clock mounted with chains outside a building"),
# ("a newly wed couple celebrating with a toast", "a newly wed couple celebrating with a baby"),
# ("a newly wed couple celebrating with a baby", "a newly wed couple celebrating with a toast"),
# ("Two people are snowboarding down a hill fast", "Two people are snowboarding down a mountain fast"),
# ("Two people are snowboarding down a mountain fast", "Two people are snowboarding down a hill fast"),
# 4
# ("a worn wooden bench beneath some shade trees", "a worn wooden hut beneath some shade trees"),
# ("a worn wooden hut beneath some shade trees", "a worn wooden bench beneath some shade trees"),
# ("a underground train station in the bronx are ", "a underground train station in the Netherlands are "),
# ("a underground train station in the Netherlands are ", "a underground train station in the bronx are "),
# ("A couple of cows on a grassy field.", "A couple of cows on a grassy pasture."),
# ("A couple of cows on a grassy pasture.", "A couple of cows on a grassy field."),
# ("A large clocktower is pictured near a fence.", "A large clocktower is pictured near a mosque."),
# ("A large clocktower is pictured near a mosque.", "A large clocktower is pictured near a fence."),
# ("Baseball players playing baseball on a baseball field.", "Young players playing baseball on a baseball field."),
# ("Young players playing baseball on a baseball field.", "Baseball players playing baseball on a baseball field."),
# 9
# ("part of a sandwich sitting on a table", "Picture of a sandwich sitting on a table"),
# ("Picture of a sandwich sitting on a table", "part of a sandwich sitting on a table"),
# ("Two Giraffes are in the wilderness, possibly eating. ", "Two Giraffes are in the freezer, possibly eating. "),
# ("Two Giraffes are in the freezer, possibly eating. ", "Two Giraffes are in the wilderness, possibly eating. "),
# ("a bunch of people in a busy area", "a group of people in a busy area"),
# ("a group of people in a busy area", "a bunch of people in a busy area"),
# ("A man on a beach flying a kite", "A man on a motorcycle flying a kite"),
# ("A man on a motorcycle flying a kite", "A man on a beach flying a kite"),
# ("Someone standing in the snow with their skii's. ", "Someone standing in the doorway with their skii's. "),
# ("Someone standing in the doorway with their skii's. ", "Someone standing in the snow with their skii's. "),
# 14
# ("A group of people looking at police motorcycles.", "A group of people looking at vintage motorcycles."),
# ("A group of people looking at vintage motorcycles.", "A group of people looking at police motorcycles."),
# ("Doughnuts sitting on a table in a bakery.", "Doughnuts sitting on a shelf in a bakery."),
# ("Doughnuts sitting on a shelf in a bakery.", "Doughnuts sitting on a table in a bakery."),
# ("A man helps his friend with his suit.", "A man helps his son with his suit."),
# ("A man helps his son with his suit.", "A man helps his friend with his suit."),
# ("A small airplane is flying in the sky.", "A small plane is flying in the sky."),
# ("A small plane is flying in the sky.", "A small airplane is flying in the sky."),
# ("Fans watching a batter take his practice swings.", "Fans watching a player take his practice swings."),
# ("Fans watching a player take his practice swings.", "Fans watching a batter take his practice swings."),
# 19
# ("A passenger jet that is on the runway.", "A fighter jet that is on the runway."),
# ("A fighter jet that is on the runway.", "A passenger jet that is on the runway."),
# ("Skier on a snowy mountain carrying a backpack.", "Snow on a snowy mountain carrying a backpack."),
# ("Snow on a snowy mountain carrying a backpack.", "Skier on a snowy mountain carrying a backpack."),
# ("A skier carving down a snowy mountain side", "A man carving down a snowy mountain side"),
# ("A man carving down a snowy mountain side", "A skier carving down a snowy mountain side"),
# ("A room with some chairs and a bookshelf.", "A room with some chairs and a fireplace."),
# ("A room with some chairs and a fireplace.", "A room with some chairs and a bookshelf."),
# ("People are playing some video games on television.", "People are playing some video games on Twitch."),
# ("People are playing some video games on Twitch.", "People are playing some video games on television."),
# 24
# ("A boy hitting a baseball on the beach.", "A boy hitting a volleyball on the beach."),
# ("A boy hitting a volleyball on the beach.", "A boy hitting a baseball on the beach."),
# ("the birds are flying next to the boat ", "the birds are flying next to the trees "),
# ("the birds are flying next to the trees ", "the birds are flying next to the boat "),
# ("The cake is shaped like a teddy bear.", "The doll is shaped like a teddy bear."),
# ("The doll is shaped like a teddy bear.", "The cake is shaped like a teddy bear."),
# ("A giraffe walking through a tree filled forest.", "A man walking through a tree filled forest."),
# ("A man walking through a tree filled forest.", "A giraffe walking through a tree filled forest."),
# ("The meat is covered with spices and vegetables. ", "The dish is covered with spices and vegetables. "),
# ("The dish is covered with spices and vegetables. ", "The meat is covered with spices and vegetables. "),
# 29
# ("Herd of zebras standing on a rocky field.", "Images of zebras standing on a rocky field."),
# ("Images of zebras standing on a rocky field.", "Herd of zebras standing on a rocky field."),
# ("White and orange flowers in a glass vase.", "White and orange flowers in a glass jar."),
# ("White and orange flowers in a glass jar.", "White and orange flowers in a glass vase."),
# ("People are standing by a small passenger train.", "People are standing by a small freight train."),
# ("People are standing by a small freight train.", "People are standing by a small passenger train."),
# ("A large yellow train moving down a track.", "A large yellow truck moving down a track."),
# ("A large yellow truck moving down a track.", "A large yellow train moving down a track."),
# ("A parking voucher machine on a snow-covered sidewalk.", "A vending voucher machine on a snow-covered sidewalk."),
# ("A vending voucher machine on a snow-covered sidewalk.", "A parking voucher machine on a snow-covered sidewalk."),
# 34
# ("An empty kitchen with black counter tops. ", "An empty fridge with black counter tops. "),
# ("An empty fridge with black counter tops. ", "An empty kitchen with black counter tops. "),
# ("a room showing a sink and some drawers", "a photo showing a sink and some drawers"),
# ("a photo showing a sink and some drawers", "a room showing a sink and some drawers"),
# ("The fruit is floating along in the water.", "The fish is floating along in the water."),
# ("The fish is floating along in the water.", "The fruit is floating along in the water."),
# ("Closeup of various oranges and bananas in pile.", " piles of various oranges and bananas in pile."),
# (" piles of various oranges and bananas in pile.", "Closeup of various oranges and bananas in pile."),
# ("A fuzzy cat lying in an open suitcase.", "A fuzzy kitten lying in an open suitcase."),
# ("A fuzzy kitten lying in an open suitcase.", "A fuzzy cat lying in an open suitcase."),
# 39
# ("A young child sits holding a stuffed bear.", "A young child sits holding a stuffed animal."),
# ("A young child sits holding a stuffed animal.", "A young child sits holding a stuffed bear."),
# ("A man on a motorcycle in a parade ", "A man on a motorcycle in a wheelchair "),
# ("A man on a motorcycle in a wheelchair ", "A man on a motorcycle in a parade "),
# ("Aerial trick performed by skateboarder wearing green shirt.", "Aerial trick performed by someone wearing green shirt."),
# ("Aerial trick performed by someone wearing green shirt.", "Aerial trick performed by skateboarder wearing green shirt."),
# ("A person with a hat and a suitcase.", "A person with a backpack and a suitcase."),
# ("A person with a backpack and a suitcase.", "A person with a hat and a suitcase."),
# ("Three people are riding on a brown elephant.", "Three people are riding on a brown motorcycle."),
# ("Three people are riding on a brown motorcycle.", "Three people are riding on a brown elephant."),
# 44
# ("Two zebras eating grass behind an open fence.", "Two zebras eating dinner behind an open fence."),
# ("Two zebras eating dinner behind an open fence.", "Two zebras eating grass behind an open fence."),
# ("a truck that transports cars on the back", "a van that transports cars on the back"),
# ("a van that transports cars on the back", "a truck that transports cars on the back"),
# ("A woman carrying skis up a snowy hill.", "A woman carrying skis up a snowy slope."),
# ("A woman carrying skis up a snowy slope.", "A woman carrying skis up a snowy hill."),
# ("A city street corner from a park view ", "A busy street corner from a park view "),
# ("A busy street corner from a park view ", "A city street corner from a park view "),
# ("A white ceramic sink next to a toilet.", "A white kitchen sink next to a toilet."),
# ("A white kitchen sink next to a toilet.", "A white ceramic sink next to a toilet."),
# 49
# ("A kitchen filled with lots of counter space.", "A space filled with lots of counter space."),
# ("A space filled with lots of counter space.", "A kitchen filled with lots of counter space."),
# ("a man on a skateboard in mid air ", "a man on a motorcycle in mid air "),
# ("a man on a motorcycle in mid air ", "a man on a skateboard in mid air "),
# ("a man in glasses is holding a spoon", "a man in glasses is holding a gun"),
# ("a man in glasses is holding a gun", "a man in glasses is holding a spoon"),
# ("Two giraffes standing in a brush covered area.", "Two giraffes standing in a brush covered pond."),
# ("Two giraffes standing in a brush covered pond.", "Two giraffes standing in a brush covered area."),
# ("A bright orange sign reads "end of roadwork". ", "A bright orange sign reads "End of roadwork". "),
# ("A bright orange sign reads "End of roadwork". ", "A bright orange sign reads "end of roadwork". "),
# 54
# ("a brown breakfast bar in a large kitchen", "a brown chocolate bar in a large kitchen"),
# ("a brown chocolate bar in a large kitchen", "a brown breakfast bar in a large kitchen"),
# ("Two cats in a chair taking their naps.", "Two cats in a cage taking their naps."),
# ("Two cats in a cage taking their naps.", "Two cats in a chair taking their naps."),
# ("a stop sign underneath some telephone wiring ", "a warning sign underneath some telephone wiring "),
# ("a warning sign underneath some telephone wiring ", "a stop sign underneath some telephone wiring "),
# ("a person at a dinner table eating salad", "a person at a picnic table eating salad"),
# ("a person at a picnic table eating salad", "a person at a dinner table eating salad"),
# ("a couple of giraffes reach for a basket ", "a couple of giraffes reach for a snack "),
# ("a couple of giraffes reach for a snack ", "a couple of giraffes reach for a basket "),
# 59
# ("A cat is sitting inside a large bathtub.", "A toddler is sitting inside a large bathtub."),
# ("A toddler is sitting inside a large bathtub.", "A cat is sitting inside a large bathtub."),
# ("An open refrigerator door on a kitchen floor.", "An open garage door on a kitchen floor."),
# ("An open garage door on a kitchen floor.", "An open refrigerator door on a kitchen floor."),
# ("Four giraffes are walking up an inclined path.", "Four giraffes are walking up an inclined slope."),
# ("Four giraffes are walking up an inclined slope.", "Four giraffes are walking up an inclined path."),
# ("A collection of paintings against a fence outside.", "A collection of paintings against a wall outside."),
# ("A collection of paintings against a wall outside.", "A collection of paintings against a fence outside."),
# ("Some people who are walking on a beach.", "Some people who are walking on a sidewalk."),
# ("Some people who are walking on a sidewalk.", "Some people who are walking on a beach."),
# 64
# ("Zieber eating grass off the ground by itself. ", "Zieber eating meat off the ground by itself. "),
# ("Zieber eating meat off the ground by itself. ", "Zieber eating grass off the ground by itself. "),
# ("A plate with a sandwich and salad greens.", "A salad with a sandwich and salad greens."),
# ("A salad with a sandwich and salad greens.", "A plate with a sandwich and salad greens."),
# ("A red boat is floating near some houses.", "A red flag is floating near some houses."),
# ("A red flag is floating near some houses.", "A red boat is floating near some houses."),
# ("A woman on a surfboard in the ocean.", "A woman on a beach in the ocean."),
# ("A woman on a beach in the ocean.", "A woman on a surfboard in the ocean."),
# ("A cat snuggling with a teddy bear's foot. ", "A kitten snuggling with a teddy bear's foot. "),
# ("A kitten snuggling with a teddy bear's foot. ", "A cat snuggling with a teddy bear's foot. "),
# 69
# ("A skateboarder is carrying groceries on his board", "A man is carrying groceries on his board"),
# ("A man is carrying groceries on his board", "A skateboarder is carrying groceries on his board"),
# ("a boy excited about his breakfast in bed", "a boy excited about his brother in bed"),
# ("a boy excited about his brother in bed", "a boy excited about his breakfast in bed"),
# ("A young girl holding a yellow tennis racquet.", "A young girl holding a yellow tennis ball."),
# ("A young girl holding a yellow tennis ball.", "A young girl holding a yellow tennis racquet."),
# ("Two railroad trains with different front cars together", "Two passenger trains with different front cars together"),
# ("Two passenger trains with different front cars together", "Two railroad trains with different front cars together"),
# ("A giraffe standing under a several tree branches.", "A man standing under a several tree branches."),
# ("A man standing under a several tree branches.", "A giraffe standing under a several tree branches."),
# 74
# ("A teenager is wearing glasses and a tie.", "A woman is wearing glasses and a tie."),
# ("A woman is wearing glasses and a tie.", "A teenager is wearing glasses and a tie."),
# ("A white toilet that has its seat up.", "A white SUV that has its seat up."),
# ("A white SUV that has its seat up.", "A white toilet that has its seat up."),
# ("A empty bench on a snow covered beach.", "A empty suitcase on a snow covered beach."),
# ("A empty suitcase on a snow covered beach.", "A empty bench on a snow covered beach."),
# ("An elephant walking through tall grass near trees. ", "An owl walking through tall grass near trees. "),
# ("An owl walking through tall grass near trees. ", "An elephant walking through tall grass near trees. "),
# ("A women who is sitting on a boat.", "A women who is sitting on a bench."),
# ("A women who is sitting on a bench.", "A women who is sitting on a boat."),
# 79
# ("The houseboat has a car in its garage.", "The houseboat has a generator in its garage."),
# ("The houseboat has a generator in its garage.", "The houseboat has a car in its garage."),
# ("An old toilet sitting next to other debris. ", "An old mattress sitting next to other debris. "),
# ("An old mattress sitting next to other debris. ", "An old toilet sitting next to other debris. "),
# ("Many oranges have been placed inside a bowl.", "Many oranges have been placed inside a refrigerator."),
# ("Many oranges have been placed inside a refrigerator.", "Many oranges have been placed inside a bowl."),
# ("a white bird is standing on a beach", "a white bird is standing on a ledge"),
# ("a white bird is standing on a ledge", "a white bird is standing on a beach"),
# ("A young boy with a video game controller.", "A young boy with a Nintendo game controller."),
# ("A young boy with a Nintendo game controller.", "A young boy with a video game controller."),
# 84
# ("A woman standing next to a computer monitor.", "A woman standing next to a computer screen."),
# ("A woman standing next to a computer screen.", "A woman standing next to a computer monitor."),
# ("a bear that is sitting on a table", "a painting that is sitting on a table"),
# ("a painting that is sitting on a table", "a bear that is sitting on a table"),
# ("Skateboarder performing aerial trick on partly cloudy day.", "Skateboarder performing aerial maneuvers on partly cloudy day."),
# ("Skateboarder performing aerial maneuvers on partly cloudy day.", "Skateboarder performing aerial trick on partly cloudy day."),
# ("an old silver and brown double parking meter", "an old grey and brown double parking meter"),
# ("an old grey and brown double parking meter", "an old silver and brown double parking meter"),
# ("A city sidewalk looking down the street ", "A city councillor looking down the street "),
# ("A city councillor looking down the street ", "A city sidewalk looking down the street "),
# 89
# ("A group of people skiing on a slope ", "A group of people skiing on a glacier "),
# ("A group of people skiing on a glacier ", "A group of people skiing on a slope "),
# ("A man in a hat riding a horse.", "A man in a wheelchair riding a horse."),
# ("A man in a wheelchair riding a horse.", "A man in a hat riding a horse."),
# ("A woman looks upon a science museum exhibit", "A woman looks upon a science fiction exhibit"),
# ("A woman looks upon a science fiction exhibit", "A woman looks upon a science museum exhibit"),
# ("A person doing a trick on a skateboard. ", "A person doing a trick on a computer. "),
# ("A person doing a trick on a computer. ", "A person doing a trick on a skateboard. "),
# ("four zebras standing in the tall dry grass", "four zebras standing in the tall drywall"),
# ("four zebras standing in the tall drywall", "four zebras standing in the tall dry grass"),
# 94
# ("A duck and baby ducks in the water.", "A duck and baby ducks in the foreground."),
# ("A duck and baby ducks in the foreground.", "A duck and baby ducks in the water."),
# ("A giraffe walking through a lush green field.", "A woman walking through a lush green field."),
# ("A woman walking through a lush green field.", "A giraffe walking through a lush green field."),
# ("a clock tower in front of some buildings ", "a tall tower in front of some buildings "),
# ("a tall tower in front of some buildings ", "a clock tower in front of some buildings "),
# ("A mother sheep with two black baby sheeps.", "A white sheep with two black baby sheeps."),
# ("A white sheep with two black baby sheeps.", "A mother sheep with two black baby sheeps."),
# ("A large clock tower towering over a city.", "A large clock tower towering over a hill."),
# ("A large clock tower towering over a hill.", "A large clock tower towering over a city."),
# 99
# ("A long horn cow resting in the grass.", "A long dead cow resting in the grass."),
# ("A long dead cow resting in the grass.", "A long horn cow resting in the grass."),
# ("A baby holding a toothbrush in it's mouth.", "A baby holding a toy in it's mouth."),
# ("A baby holding a toy in it's mouth.", "A baby holding a toothbrush in it's mouth."),
# ("A large bird floating out in the water.", "A large fish floating out in the water."),
# ("A large fish floating out in the water.", "A large bird floating out in the water."),
# ("The giraffe is a truly majestic tall animal. ", "The unicorn is a truly majestic tall animal. "),
# ("The unicorn is a truly majestic tall animal. ", "The giraffe is a truly majestic tall animal. "),
# ("two train on a track near a building ", "two cars on a track near a building "),
# ("two cars on a track near a building ", "two train on a track near a building "),
# 104
# ("Two people flying a kite in the snow.", "Two people flying a helicopter in the snow."),
# ("Two people flying a helicopter in the snow.", "Two people flying a kite in the snow."),
# ("A brown bench sitting next to a forest.", "A brown bear sitting next to a forest."),
# ("A brown bear sitting next to a forest.", "A brown bench sitting next to a forest."),
# ("there is a green clock in the street", "there is a green light in the street"),
# ("there is a green light in the street", "there is a green clock in the street"),
# ("The back view of white iPhone mobile phone.", "The backside of white iPhone mobile phone."),
# ("The backside of white iPhone mobile phone.", "The back view of white iPhone mobile phone."),
# ("A furry cat sits on a blue chair. ", "A furry kitten sits on a blue chair. "),
# ("A furry kitten sits on a blue chair. ", "A furry cat sits on a blue chair. "),
# 109
# ("A large sandwich has bread, cheese and lettuce.", "A large salad has bread, cheese and lettuce."),
# ("A large salad has bread, cheese and lettuce.", "A large sandwich has bread, cheese and lettuce."),
# ("stop sign on a street of a cemetary", "stop sign on a wall of a cemetary"),
# ("stop sign on a wall of a cemetary", "stop sign on a street of a cemetary"),
# ("A pizza being made within the oven ", "A sausage being made within the oven "),
# ("A sausage being made within the oven ", "A pizza being made within the oven "),
# ("A street sign above an orange detour sign.", "A yellow sign above an orange detour sign."),
# ("A yellow sign above an orange detour sign.", "A street sign above an orange detour sign."),
# ("A television and some chairs in a room.", "A table and some chairs in a room."),
# ("A table and some chairs in a room.", "A television and some chairs in a room."),
# 114
# ("Three elephants standing in the grass near water.", "Three elephants standing in the forest near water."),
# ("Three elephants standing in the forest near water.", "Three elephants standing in the grass near water."),
# ("a close up of a plate with food", "a close up of a restaurant with food"),
# ("a close up of a restaurant with food", "a close up of a plate with food"),
# ("Multiple pumpkins and a skeleton on the wall.", "Multiple pumpkins and a mural on the wall."),
# ("Multiple pumpkins and a mural on the wall.", "Multiple pumpkins and a skeleton on the wall."),
# ("A propellor airplane is on a grassy runway.", "A propellor plane is on a grassy runway."),
# ("A propellor plane is on a grassy runway.", "A propellor airplane is on a grassy runway."),
# ("A bear walking on grass near mountains. ", "A man walking on grass near mountains. "),
# ("A man walking on grass near mountains. ", "A bear walking on grass near mountains. "),
# 119
# ("A waiting area in an airport terminal ", "A waiting queue in an airport terminal "),
# ("A waiting queue in an airport terminal ", "A waiting area in an airport terminal "),
# ("Two signs on a pole near some water.", "Two signs on a highway near some water."),
# ("Two signs on a highway near some water.", "Two signs on a pole near some water."),
# ("A blue plate loaded with broccoli and cauliflower", "A blue salad loaded with broccoli and cauliflower"),
# ("A blue salad loaded with broccoli and cauliflower", "A blue plate loaded with broccoli and cauliflower"),
# ("A refrigerator freezer next to a  wall.", "A small freezer next to a  wall."),
# ("A small freezer next to a  wall.", "A refrigerator freezer next to a  wall."),
# ("Boy flying his kite outside in the yard.", "Boy flying his dog outside in the yard."),
# ("Boy flying his dog outside in the yard.", "Boy flying his kite outside in the yard."),
# 124
# ("A large group of birds in the water.", "A large group of birds in the wild."),
# ("A large group of birds in the wild.", "A large group of birds in the water."),
# ("A baby grabs a magnet from the refrigerator. ", "A baby grabs a toy from the refrigerator. "),
# ("A baby grabs a toy from the refrigerator. ", "A baby grabs a magnet from the refrigerator. "),
# ("wheat bread with chocolate and sliced bananas ", "White bread with chocolate and sliced bananas "),
# ("White bread with chocolate and sliced bananas ", "wheat bread with chocolate and sliced bananas "),
# ("they are two laptops with a green screen.", "they are two laptops with a green logo."),
# ("they are two laptops with a green logo.", "they are two laptops with a green screen."),
# ("Some street signs near a big bridge overpass.", "Some posted signs near a big bridge overpass."),
# ("Some posted signs near a big bridge overpass.", "Some street signs near a big bridge overpass."),
# 129
# ("Two brown bears interacting in a rocky area.", "Two brown bears interacting in a rocky pasture."),
# ("Two brown bears interacting in a rocky pasture.", "Two brown bears interacting in a rocky area."),
# ("a spin brush tooth brush on the sink", "a tooth brush tooth brush on the sink"),
# ("a tooth brush tooth brush on the sink", "a spin brush tooth brush on the sink"),
# ("Guys look through the cabinets and refrigerator. ", "Guys look through the cabinets and cabinets. "),
# ("Guys look through the cabinets and cabinets. ", "Guys look through the cabinets and refrigerator. "),
# ("a spooky looking hotel resort in the hills", "a spooky looking ski resort in the hills"),
# ("a spooky looking ski resort in the hills", "a spooky looking hotel resort in the hills"),
# ("A hotel room with two separate twin beds.", "A single room with two separate twin beds."),
# ("A single room with two separate twin beds.", "A hotel room with two separate twin beds."),
# 134
# ("A tall building with a large white statue.", "A tall building with a large white dome."),
# ("A tall building with a large white dome.", "A tall building with a large white statue."),
# ("Pizza with everything on it sitting on counter.  ", " fridge with everything on it sitting on counter.  "),
# (" fridge with everything on it sitting on counter.  ", "Pizza with everything on it sitting on counter.  "),
# ("A bathroom with a bathtub and a toilet.", "A house with a bathtub and a toilet."),
# ("A house with a bathtub and a toilet.", "A bathroom with a bathtub and a toilet."),
# ("A quarter of a cake on a plate", "A picture of a cake on a plate"),
# ("A picture of a cake on a plate", "A quarter of a cake on a plate"),
# ("Men standing on a tennis court playing tennis.", "Woman standing on a tennis court playing tennis."),
# ("Woman standing on a tennis court playing tennis.", "Men standing on a tennis court playing tennis."),
# 139
# ("A white bus driving past a tall building.", "A white sedan driving past a tall building."),
# ("A white sedan driving past a tall building.", "A white bus driving past a tall building."),
# ("a person riding skis on a snowy surface", "a person riding skis on a snowy mountain"),
# ("a person riding skis on a snowy mountain", "a person riding skis on a snowy surface"),
# ("The giraffe is eating from his feeding bowl.", "The boy is eating from his feeding bowl."),
# ("The boy is eating from his feeding bowl.", "The giraffe is eating from his feeding bowl."),
# ("a big umbrella sitting on the beach ", "a big fish sitting on the beach "),
# ("a big fish sitting on the beach ", "a big umbrella sitting on the beach "),
# ("The man is standing beside a busy street.", "The man is standing beside a busy intersection."),
# ("The man is standing beside a busy intersection.", "The man is standing beside a busy street."),
# 144
# ("A picture of a cluttered home office desk.", "A picture of a cluttered Microsoft office desk."),
# ("A picture of a cluttered Microsoft office desk.", "A picture of a cluttered home office desk."),
# ("A bird aggressively protects his patch of turf.", "A farmer aggressively protects his patch of turf."),
# ("A farmer aggressively protects his patch of turf.", "A bird aggressively protects his patch of turf."),
# ("Large marble looking building with a steeple top.", "Large rectangular looking building with a steeple top."),
# ("Large rectangular looking building with a steeple top.", "Large marble looking building with a steeple top."),
# ("a blind cat is sitting in a cage", "a blind monkey is sitting in a cage"),
# ("a blind monkey is sitting in a cage", "a blind cat is sitting in a cage"),
# ("Giraffe reaching into basked with trees in background", "Giraffe reaching into basked with trees in camouflage"),
# ("Giraffe reaching into basked with trees in camouflage", "Giraffe reaching into basked with trees in background"),
# 149
# ("a couple of knifes are near a vegetable", "a couple of knifes are near a tree"),
# ("a couple of knifes are near a tree", "a couple of knifes are near a vegetable"),
# ("A stained glassed window shines over a clock.", "A stained glassed candle shines over a clock."),
# ("A stained glassed candle shines over a clock.", "A stained glassed window shines over a clock."),
# ("People walking down a sidewalk passing Chinese restaurants.", "People walking down a street passing Chinese restaurants."),
# ("People walking down a street passing Chinese restaurants.", "People walking down a sidewalk passing Chinese restaurants."),
# ("some males on some sand are playing volleyball", "some males on some beaches are playing volleyball"),
# ("some males on some beaches are playing volleyball", "some males on some sand are playing volleyball"),
# ("A laptop and keyboard sit on a desk.  ", "A mouse and keyboard sit on a desk.  "),
# ("A mouse and keyboard sit on a desk.  ", "A laptop and keyboard sit on a desk.  "),
# 154
# ("An umbrella is opened over an outdoor table.", "An umbrella is opened over an outdoor patio."),
# ("An umbrella is opened over an outdoor patio.", "An umbrella is opened over an outdoor table."),
# ("A person riding the waves on a surfboard.", "A person riding the waves on a bicycle."),
# ("A person riding the waves on a bicycle.", "A person riding the waves on a surfboard."),
# ("a sexy women that is on a skateboard", "a sexy women that is on a mission"),
# ("a sexy women that is on a mission", "a sexy women that is on a skateboard"),
# ("The boats are sailing out on the water.", "The boats are sailing out on the beach."),
# ("The boats are sailing out on the beach.", "The boats are sailing out on the water."),
# ("A guy does a trick on a skateboard.", "A squirrel does a trick on a skateboard."),
# ("A squirrel does a trick on a skateboard.", "A guy does a trick on a skateboard."),
# 159
# ("a couple of cellphones are on a table", "a couple of cellphones are on a rampage"),
# ("a couple of cellphones are on a rampage", "a couple of cellphones are on a table"),
# ("A group of birds flying above the beach.", "A group of birds flying above the clouds."),
# ("A group of birds flying above the clouds.", "A group of birds flying above the beach."),
# ("A man throwing a frisbee in a park ", "A man throwing a rock in a park "),
# ("A man throwing a rock in a park ", "A man throwing a frisbee in a park "),
# ("The face of a large brass antique clock.", "The face of a large brass antique statue."),
# ("The face of a large brass antique statue.", "The face of a large brass antique clock."),
# ("A woman is riding an orange sports motorcycle.", "A woman is riding an orange sports bike."),
# ("A woman is riding an orange sports bike.", "A woman is riding an orange sports motorcycle."),
# 164
# ("a close up of a vandalized stop sign ", "a mock up of a vandalized stop sign "),
# ("a mock up of a vandalized stop sign ", "a close up of a vandalized stop sign "),
# ("Two white sheep are resting in a field.", "Two white sheep are resting in a barn."),
# ("Two white sheep are resting in a barn.", "Two white sheep are resting in a field."),
# ("A multicolor passenger train waiting at a platform.", "A multicolor passenger train waiting at a station."),
# ("A multicolor passenger train waiting at a station.", "A multicolor passenger train waiting at a platform."),
# ("A foreign street sign that's covered in snow.", "A foreign aid sign that's covered in snow."),
# ("A foreign aid sign that's covered in snow.", "A foreign street sign that's covered in snow."),
# ("A train engine carrying carts down a track.", "A diesel engine carrying carts down a track."),
# ("A diesel engine carrying carts down a track.", "A train engine carrying carts down a track."),
# 169
# ("A giraffe that is standing behind a tree.", "A squirrel that is standing behind a tree."),
# ("A squirrel that is standing behind a tree.", "A giraffe that is standing behind a tree."),
# ("A white refrigerator in a very small kitchen.", "A white elephant in a very small kitchen."),
# ("A white elephant in a very small kitchen.", "A white refrigerator in a very small kitchen."),
# ("A brown bear lounging on a gray rock", "A brown bear lounging on a gray couch"),
# ("A brown bear lounging on a gray couch", "A brown bear lounging on a gray rock"),
# ("A beautiful young woman buckling her seat belt.", "A beautiful young woman buckling her wedding belt."),
# ("A beautiful young woman buckling her wedding belt.", "A beautiful young woman buckling her seat belt."),
# ("three sheep standing together eating some grass ", "three sheep standing together eating some bread "),
# ("three sheep standing together eating some bread ", "three sheep standing together eating some grass "),
# 174
# ("Family and friends are together at the beach.", "Family and friends are together at the vigil."),
# ("Family and friends are together at the vigil.", "Family and friends are together at the beach."),
# ("a baseball player batting up at home plate", "a baseball bat batting up at home plate"),
# ("a baseball bat batting up at home plate", "a baseball player batting up at home plate"),
# ("A street pole is loaded with different signs.", "A totem pole is loaded with different signs."),
# ("A totem pole is loaded with different signs.", "A street pole is loaded with different signs."),
# ("A sink with cracked porcelain highlights this bathroom", "A wall with cracked porcelain highlights this bathroom"),
# ("A wall with cracked porcelain highlights this bathroom", "A sink with cracked porcelain highlights this bathroom"),
# ("Street light with street signs that restrict traffic.", " red light with street signs that restrict traffic."),
# (" red light with street signs that restrict traffic.", "Street light with street signs that restrict traffic."),
# 179
# ("A large building with people gathered in front.", "A large crowd with people gathered in front."),
# ("A large crowd with people gathered in front.", "A large building with people gathered in front."),
# ("A firehydrant sitting in some grass and snow", "A firehydrant sitting in some grass and weeds"),
# ("A firehydrant sitting in some grass and weeds", "A firehydrant sitting in some grass and snow"),
# ("A man is holding a yellow frisbee outside", "A man is holding a yellow flag outside"),
# ("A man is holding a yellow flag outside", "A man is holding a yellow frisbee outside"),
# ("a bear is sitting in a green field", "a woman is sitting in a green field"),
# ("a woman is sitting in a green field", "a bear is sitting in a green field"),
# ("Bunches of bananas are displayed in a shop.", "Bunches of bananas are displayed in a basket."),
# ("Bunches of bananas are displayed in a basket.", "Bunches of bananas are displayed in a shop."),
# 184
# ("An old hydrant shoots water into the street.", "An old man shoots water into the street."),
# ("An old man shoots water into the street.", "An old hydrant shoots water into the street."),
# ("A person with a suitcase on a street.", "A person with a knife on a street."),
# ("A person with a knife on a street.", "A person with a suitcase on a street."),
# ("A dog resting on the beach at dusk.", "A dolphin resting on the beach at dusk."),
# ("A dolphin resting on the beach at dusk.", "A dog resting on the beach at dusk."),
# ("Two girls eating donuts in a house. ", "Two girls eating donuts in a cafeteria. "),
# ("Two girls eating donuts in a cafeteria. ", "Two girls eating donuts in a house. "),
# ("Person in a green park fling a kite.", "Person in a green bikini fling a kite."),
# ("Person in a green bikini fling a kite.", "Person in a green park fling a kite."),
# 189
# ("A man grinding his skateboard on a rail.", "A man grinding his teeth on a rail."),
# ("A man grinding his teeth on a rail.", "A man grinding his skateboard on a rail."),
# ("A man holding a child in high water.", "A man holding a child in high school."),
# ("A man holding a child in high school.", "A man holding a child in high water."),
# ("A bridge with several signs and a cityscape.  ", "A plaza with several signs and a cityscape.  "),
# ("A plaza with several signs and a cityscape.  ", "A bridge with several signs and a cityscape.  "),
# ("a calico kitty sleeping in an orange chair ", "a calico kitty sleeping in an orange blanket "),
# ("a calico kitty sleeping in an orange blanket ", "a calico kitty sleeping in an orange chair "),
# ("A tennis player jumps and hits a ball.", "A baseball player jumps and hits a ball."),
# ("A baseball player jumps and hits a ball.", "A tennis player jumps and hits a ball."),
# 194
# ("A gross dirty toilet in a unmaintained bathroom. ", "A gross dirty mess in a unmaintained bathroom. "),
# ("A gross dirty mess in a unmaintained bathroom. ", "A gross dirty toilet in a unmaintained bathroom. "),
# ("Fried fish and french fries served on paper.", "Fried chicken and french fries served on paper."),
# ("Fried chicken and french fries served on paper.", "Fried fish and french fries served on paper."),
# ("a plate with chicken and some vegetables together", "a salad with chicken and some vegetables together"),
# ("a salad with chicken and some vegetables together", "a plate with chicken and some vegetables together"),
# ("A strange plant hanging off a banana tree.", "A strange plant hanging off a Christmas tree."),
# ("A strange plant hanging off a Christmas tree.", "A strange plant hanging off a banana tree."),
# ("A person feeding a cat with a banana", "A person feeding a squirrel with a banana"),
# ("A person feeding a squirrel with a banana", "A person feeding a cat with a banana"),
# 199
# ("The plate is holding a sandwich and salad.", "The waitress is holding a sandwich and salad."),
# ("The waitress is holding a sandwich and salad.", "The plate is holding a sandwich and salad."),
# ("A brick clock tower ascending towards the heavens", "A brick clocktower ascending towards the heavens"),
# ("A brick clocktower ascending towards the heavens", "A brick clock tower ascending towards the heavens"),
# ("Four people playing frisbee on a soccer field.", "Four people playing soccer on a soccer field."),
# ("Four people playing soccer on a soccer field.", "Four people playing frisbee on a soccer field."),
# ("A small bird is perched on a birdfeeder.", "A small bird is perched on a tree."),
# ("A small bird is perched on a tree.", "A small bird is perched on a birdfeeder."),
# ("A group of men standing around a room.", "A group of men standing around a table."),
# ("A group of men standing around a table.", "A group of men standing around a room."),
# 204
# ("a giraffe staring right into the camera ", "a man staring right into the camera "),
# ("a man staring right into the camera ", "a giraffe staring right into the camera "),
# ("A construction truck is surrounded by a fence.", "A pickup truck is surrounded by a fence."),
# ("A pickup truck is surrounded by a fence.", "A construction truck is surrounded by a fence."),
# ("A group of children are feeding an animal.", "A group of children are feeding an elephant."),
# ("A group of children are feeding an elephant.", "A group of children are feeding an animal."),
# ("Red double decker bus waiting to load passengers
# ", "Red double speed bus waiting to load passengers
# "),
# ("Red double speed bus waiting to load passengers
# ", "Red double decker bus waiting to load passengers
# "),
# ("a table with a vase with many flowers", "a tree with a vase with many flowers"),
# ("a tree with a vase with many flowers", "a table with a vase with many flowers"),
# 209
# ("A man surfing waves on his surf board", "A man surfing waves on his surfboard"),
# ("A man surfing waves on his surfboard", "A man surfing waves on his surf board"),
# ("a couple of animals walking around a farm ", "a couple of animals walking around a bush "),
# ("a couple of animals walking around a bush ", "a couple of animals walking around a farm "),
# ("a giraffe reaching up to eat some leaves ", "a woman reaching up to eat some leaves "),
# ("a woman reaching up to eat some leaves ", "a giraffe reaching up to eat some leaves "),
# ("A colorful public restroom focused on the sinks.", "A colorful public forum focused on the sinks."),
# ("A colorful public forum focused on the sinks.", "A colorful public restroom focused on the sinks."),
# ("A bird that is playing in the snow.", "A squirrel that is playing in the snow."),
# ("A squirrel that is playing in the snow.", "A bird that is playing in the snow."),
# 214
# ("Two guys standing in a room with remotes.", "Two guys standing in a booth with remotes."),
# ("Two guys standing in a booth with remotes.", "Two guys standing in a room with remotes."),
# ("A plate filled with chocolate and vanilla cupcakes. ", "A cup filled with chocolate and vanilla cupcakes. "),
# ("A cup filled with chocolate and vanilla cupcakes. ", "A plate filled with chocolate and vanilla cupcakes. "),
# ("People are standing near an airport ticket kiosk.", "People are standing near an airport security kiosk."),
# ("People are standing near an airport security kiosk.", "People are standing near an airport ticket kiosk."),
# ("An advanced skateboarder is performing an airborn maneuver. ", "An advanced pilot is performing an airborn maneuver. "),
# ("An advanced pilot is performing an airborn maneuver. ", "An advanced skateboarder is performing an airborn maneuver. "),
# ("a dog in a field near a fence ", "a sheep in a field near a fence "),
# ("a sheep in a field near a fence ", "a dog in a field near a fence "),
# 219
# ("Two cars are waiting at a stop light.", "Two cars are waiting at a stoplight."),
# ("Two cars are waiting at a stoplight.", "Two cars are waiting at a stop light."),
# ("A large airplane is on the airport runway.", "A large hangar is on the airport runway."),
# ("A large hangar is on the airport runway.", "A large airplane is on the airport runway."),
# ("A person serving a sandwich on a spatula.", "A person serving a meal on a spatula."),
# ("A person serving a meal on a spatula.", "A person serving a sandwich on a spatula."),
# ("THE DUMP TRUCK AND THE CRANE ARE WORKING ", "THE BIG TRUCK AND THE CRANE ARE WORKING "),
# ("THE BIG TRUCK AND THE CRANE ARE WORKING ", "THE DUMP TRUCK AND THE CRANE ARE WORKING "),
# ("Two people are shown holding a stop sign.", "Two people are shown holding a peace sign."),
# ("Two people are shown holding a peace sign.", "Two people are shown holding a stop sign."),
# 224
# ("A woman feeding a giraffe under a tent. ", "A woman feeding a kitten under a tent. "),
# ("A woman feeding a kitten under a tent. ", "A woman feeding a giraffe under a tent. "),
# ("A man on a surfboard in the water.", "A man on a raft in the water."),
# ("A man on a raft in the water.", "A man on a surfboard in the water."),
# ("Two people wearing skis traveling through the snow.", "Two people wearing skis traveling through the woods."),
# ("Two people wearing skis traveling through the woods.", "Two people wearing skis traveling through the snow."),
# ("Small monkey eating fruit sitting on a rock. ", "Small children eating fruit sitting on a rock. "),
# ("Small children eating fruit sitting on a rock. ", "Small monkey eating fruit sitting on a rock. "),
# ("Thin black and white vase with black flowers.", "Thin black and white dresses with black flowers."),
# ("Thin black and white dresses with black flowers.", "Thin black and white vase with black flowers."),
# 229
# ("The sailboat became beached during the recent storm.", "The dam became beached during the recent storm."),
# ("The dam became beached during the recent storm.", "The sailboat became beached during the recent storm."),
# ("A close up of flowers in a vase.", "A pile up of flowers in a vase."),
# ("A pile up of flowers in a vase.", "A close up of flowers in a vase."),
# ("A birthday cake with English and Chinese characters.", "A chocolate cake with English and Chinese characters."),
# ("A chocolate cake with English and Chinese characters.", "A birthday cake with English and Chinese characters."),
# ("A food entree is served on a plate.", "A food item is served on a plate."),
# ("A food item is served on a plate.", "A food entree is served on a plate."),
# ("Several birds are walking along a muddy field.", "Several birds are walking along a muddy trail."),
# ("Several birds are walking along a muddy trail.", "Several birds are walking along a muddy field."),
# 234
# ("The pizza with chicken on it looks delicious.", "The burger with chicken on it looks delicious."),
# ("The burger with chicken on it looks delicious.", "The pizza with chicken on it looks delicious."),
# ("A bench sitting on top of a hillside.", "A man sitting on top of a hillside."),
# ("A man sitting on top of a hillside.", "A bench sitting on top of a hillside."),
# ("A single horse walking on a rocky trail.", "A single woman walking on a rocky trail."),
# ("A single woman walking on a rocky trail.", "A single horse walking on a rocky trail."),
# ("a shadow of a man on an umbrella ", "a picture of a man on an umbrella "),
# ("a picture of a man on an umbrella ", "a shadow of a man on an umbrella "),
# ("a person riding skis on a snowy surface", "a person riding skis on a snowy mountain"),
# ("a person riding skis on a snowy mountain", "a person riding skis on a snowy surface"),
# 239
# ("An old kitchen with a sink and dishwasher.", "An old refrigerator with a sink and dishwasher."),
# ("An old refrigerator with a sink and dishwasher.", "An old kitchen with a sink and dishwasher."),
# ("A person holding an umbrella in a garage.", "A person holding an iPad in a garage."),
# ("A person holding an iPad in a garage.", "A person holding an umbrella in a garage."),
# ("Rural train depot, level crossing and buildings ", "Rural train tracks, level crossing and buildings "),
# ("Rural train tracks, level crossing and buildings ", "Rural train depot, level crossing and buildings "),
# ("a clean kitchen with 4 stools in it.", "a clean tub with 4 stools in it."),
# ("a clean tub with 4 stools in it.", "a clean kitchen with 4 stools in it."),
# ("A group of people gather around a plane.", "A group of people gather around a table."),
# ("A group of people gather around a table.", "A group of people gather around a plane."),
# 244
# ("A baseball player is swinging a baseball bat.", "A baseball bat is swinging a baseball bat."),
# ("A baseball bat is swinging a baseball bat.", "A baseball player is swinging a baseball bat."),
# ("The large blue train is covered with rust.", "The large blue screen is covered with rust."),
# ("The large blue screen is covered with rust.", "The large blue train is covered with rust."),
# ("A small hotel room with a king bed.", "A small dining room with a king bed."),
# ("A small dining room with a king bed.", "A small hotel room with a king bed."),
# ("Snowboarder sitting for a majestic scenic photo ", "Man sitting for a majestic scenic photo "),
# ("Man sitting for a majestic scenic photo ", "Snowboarder sitting for a majestic scenic photo "),
# ("A elephant walking with it's trunk held out. ", "A deer walking with it's trunk held out. "),
# ("A deer walking with it's trunk held out. ", "A elephant walking with it's trunk held out. "),
# 249
# ("The boy jumped the skateboard onto the bench.", "The boy jumped the rope onto the bench."),
# ("The boy jumped the rope onto the bench.", "The boy jumped the skateboard onto the bench."),
# ("A young man doing tricks on a skateboard", "A young man doing tricks on a bicycle"),
# ("A young man doing tricks on a bicycle", "A young man doing tricks on a skateboard"),
# ("A blue kite is flying in the sky", "A blue butterfly is flying in the sky"),
# ("A blue butterfly is flying in the sky", "A blue kite is flying in the sky"),
# ("Two horses on a beach near the water", "Two horses on a horse near the water"),
# ("Two horses on a horse near the water", "Two horses on a beach near the water"),
# ("People are riding their horses in the parade.", "People are riding their horses in the streets."),
# ("People are riding their horses in the streets.", "People are riding their horses in the parade."),
# 254
# ("A distant airplane flying between two large buildings.", "A distant drone flying between two large buildings."),
# ...
# ("Someone who is laying down under a suitcase.", "Someone who is laying down under a tree."),
# ("Someone who is laying down under a tree.", "Someone who is laying down under a suitcase."),
# ("A freeway emptied without any cars or humans. ", "A desert emptied without any cars or humans. "),
# ("A desert emptied without any cars or humans. ", "A freeway emptied without any cars or humans. "),
# ("A family sitting around playing with an Atari. ", "A kid sitting around playing with an Atari. "),
# ("A kid sitting around playing with an Atari. ", "A family sitting around playing with an Atari. "),
# ("An airplane is parked on the large runway.", "An airplane is parked on the large island."),
# ("An airplane is parked on the large island.", "An airplane is parked on the large runway."),
# 419
# ("Some zebra and deer grazing in a field.", "Some sheep and deer grazing in a field."),
# ("Some sheep and deer grazing in a field.", "Some zebra and deer grazing in a field."),
# ("A skier is going through bumpy snow hills.", "A train is going through bumpy snow hills."),
# ("A train is going through bumpy snow hills.", "A skier is going through bumpy snow hills."),
# ("Men in an industrial kitchen preparing various items.", "Working in an industrial kitchen preparing various items."),
# ("Working in an industrial kitchen preparing various items.", "Men in an industrial kitchen preparing various items."),
# ("A laptop on a bed in a room.", "A mattress on a bed in a room."),
# ("A mattress on a bed in a room.", "A laptop on a bed in a room."),
# ("A parked motorcycle next to a green tent.", "A parked car next to a green tent."),
# ("A parked car next to a green tent.", "A parked motorcycle next to a green tent."),
# 424
# ("Monkey standing behind two zebras as they graze.", "Children standing behind two zebras as they graze."),
# ("Children standing behind two zebras as they graze.", "Monkey standing behind two zebras as they graze."),
# ("Two horses standing in the grass and sand.", "Two horses standing in the mud and sand."),
# ("Two horses standing in the mud and sand.", "Two horses standing in the grass and sand."),
# ("A restroom with a bathtub and a toilet.", "A house with a bathtub and a toilet."),
# ("A house with a bathtub and a toilet.", "A restroom with a bathtub and a toilet."),
# ("Three hand formed clay pots with dripping paint", "Three hand formed ceramic pots with dripping paint"),
# ("Three hand formed ceramic pots with dripping paint", "Three hand formed clay pots with dripping paint"),
# ("a person in a kitchen area preparing food", "a person in a kitchen table preparing food"),
# ("a person in a kitchen table preparing food", "a person in a kitchen area preparing food"),
# 429
# ("A cat eating a sandwich on a plate.", "A woman eating a sandwich on a plate."),
# ("A woman eating a sandwich on a plate.", "A cat eating a sandwich on a plate."),
# ("A stove standing next to a fridge freezer ", "A man standing next to a fridge freezer "),
# ("A man standing next to a fridge freezer ", "A stove standing next to a fridge freezer "),
# ("Locomotive pulling cars on tracks in outdoor area.", "Police pulling cars on tracks in outdoor area."),
# ("Police pulling cars on tracks in outdoor area.", "Locomotive pulling cars on tracks in outdoor area."),
# ("Toilet with indefinite end because of bright light", "Life with indefinite end because of bright light"),
# ("Life with indefinite end because of bright light", "Toilet with indefinite end because of bright light"),
# ("Two teenagers catch the bottom of a wave", "Two teenagers catch the bottom of a lake"),
# ("Two teenagers catch the bottom of a lake", "Two teenagers catch the bottom of a wave"),
# 434
# ("Children playing on and around a giraffe sculpture.", "Children playing on and around a Lego sculpture."),
# ("Children playing on and around a Lego sculpture.", "Children playing on and around a giraffe sculpture."),
# ("A skateboarder preforming tricks on a half pipe. ", "A magician preforming tricks on a half pipe. "),
# ("A magician preforming tricks on a half pipe. ", "A skateboarder preforming tricks on a half pipe. "),
# ("Several apples and pears sit on a surface.", "Several apples and pears sit on a shelf."),
# ("Several apples and pears sit on a shelf.", "Several apples and pears sit on a surface."),
# ("A pitcher winding up to throw a fastball.", "A pitcher winding up to throw a pitch."),
# ("A pitcher winding up to throw a pitch.", "A pitcher winding up to throw a fastball."),
# ("PEOPLE CELEBRATING WITH CHOCOLATE CAKE AND WINE ", "PEOPLE CELEBRATING WITH CHOCOLATE CAKE AND FIRE "),
# ("PEOPLE CELEBRATING WITH CHOCOLATE CAKE AND FIRE ", "PEOPLE CELEBRATING WITH CHOCOLATE CAKE AND WINE "),
# 439
# ("A cat that is sitting on some cushions.", "A kitten that is sitting on some cushions."),
# ("A kitten that is sitting on some cushions.", "A cat that is sitting on some cushions."),
# ("A woman bathing her dog in the sink", "A woman bathing her dog in the shower"),
# ("A woman bathing her dog in the shower", "A woman bathing her dog in the sink"),
# ("A street sign is underneath a concrete overpass. ", "A warning sign is underneath a concrete overpass. "),
# ("A warning sign is underneath a concrete overpass. ", "A street sign is underneath a concrete overpass. "),
# ("A young woman playing tennis in a tournament.", "A young woman playing volleyball in a tournament."),
# ("A young woman playing volleyball in a tournament.", "A young woman playing tennis in a tournament."),
# ("A prop plane is flying through the sky.", "A fighter plane is flying through the sky."),
# ("A fighter plane is flying through the sky.", "A prop plane is flying through the sky."),
# 444
# ("A metro train entering into a train station", "A commuter train entering into a train station"),
# ("A commuter train entering into a train station", "A metro train entering into a train station"),
# ("The track is round and made of clay.", "The sculpture is round and made of clay."),
# ("The sculpture is round and made of clay.", "The track is round and made of clay."),
# ("A person rides belly-down on a surfboard. ", "A person rides belly-down on a bicycle. "),
# ("A person rides belly-down on a bicycle. ", "A person rides belly-down on a surfboard. "),
# ("A small sandwich sits on a white plate. ", "A small egg sits on a white plate. "),
# ("A small egg sits on a white plate. ", "A small sandwich sits on a white plate. "),
# ("A live guard truck parked on a beach.", "A live lobster truck parked on a beach."),
# ("A live lobster truck parked on a beach.", "A live guard truck parked on a beach."),
# 449
# ("a busy street with a green stoplight arrow.", "a busy intersection with a green stoplight arrow."),
# ("a busy intersection with a green stoplight arrow.", "a busy street with a green stoplight arrow."),
# ("a mess of various clothing on a chair ", "a mess of various shapes on a chair "),
# ("a mess of various shapes on a chair ", "a mess of various clothing on a chair "),
# ("a close up of a disassembled remote control  ", "a mock up of a disassembled remote control  "),
# ("a mock up of a disassembled remote control  ", "a close up of a disassembled remote control  "),
# ("Two giraffes stand in sand inside an enclosure. ", "Two giraffes stand in formation inside an enclosure. "),
# ("Two giraffes stand in formation inside an enclosure. ", "Two giraffes stand in sand inside an enclosure. "),
# ("Assorted food items displayed on light blue plates.", "Assorted menu items displayed on light blue plates."),
# ("Assorted menu items displayed on light blue plates.", "Assorted food items displayed on light blue plates."),
# 454
# ("Sheep graze in a lushly green mountain meadow", "Children graze in a lushly green mountain meadow"),
# ("Children graze in a lushly green mountain meadow", "Sheep graze in a lushly green mountain meadow"),
# ("A stop sign outside of a brick building.", "A neon sign outside of a brick building."),
# ("A neon sign outside of a brick building.", "A stop sign outside of a brick building."),
# ("A square pizza on a wooden cutting board.", "A homemade pizza on a wooden cutting board."),
# ("A homemade pizza on a wooden cutting board.", "A square pizza on a wooden cutting board."),
# ("Two people that are sitting on a table.", "Two people that are sitting on a bench."),
# ("Two people that are sitting on a bench.", "Two people that are sitting on a table."),
# ("A PICTURE OF ALL WHITE IN A BATHROOM ", "A GROUP OF ALL WHITE IN A BATHROOM "),
# ("A GROUP OF ALL WHITE IN A BATHROOM ", "A PICTURE OF ALL WHITE IN A BATHROOM "),
# 459
# ("The man is running during a baseball game.", "The man is running during a football game."),
# ("The man is running during a football game.", "The man is running during a baseball game."),
# ("People with drinks standing around a kitchen island.", "People with drinks standing around a deserted island."),
# ("People with drinks standing around a deserted island.", "People with drinks standing around a kitchen island."),
# ("A white bus is driving down the street", "A white SUV is driving down the street"),
# ("A white SUV is driving down the street", "A white bus is driving down the street"),
# ("two horses are walking through a river together", "two horses are walking through a forest together"),
# ("two horses are walking through a forest together", "two horses are walking through a river together"),
# ("A dog jumping to catch a flying frisbee", "A squirrel jumping to catch a flying frisbee"),
# ("A squirrel jumping to catch a flying frisbee", "A dog jumping to catch a flying frisbee"),
# 464
# ("This is the grill of a large truck.", "This is the underside of a large truck."),
# ("This is the underside of a large truck.", "This is the grill of a large truck."),
# ("two people sitting near sheep on hay ", "two people sitting near cows on hay "),
# ("two people sitting near cows on hay ", "two people sitting near sheep on hay "),
# ("Baby bear climbing large rock near pine tree.", "Baby elephant climbing large rock near pine tree."),
# ("Baby elephant climbing large rock near pine tree.", "Baby bear climbing large rock near pine tree."),
# ("A store filled with bathroom equipment and accessories.", "A store filled with bathroom supplies and accessories."),
# ("A store filled with bathroom supplies and accessories.", "A store filled with bathroom equipment and accessories."),
# ("A cat laying on top of a couch.", "A kitten laying on top of a couch."),
# ("A kitten laying on top of a couch.", "A cat laying on top of a couch."),
# 469
# ("a person in a field with a frisbee ", "a person in a bikini with a frisbee "),
# ("a person in a bikini with a frisbee ", "a person in a field with a frisbee "),
# ("There is a plane turning in mid air", "There is a helicopter turning in mid air"),
# ("There is a helicopter turning in mid air", "There is a plane turning in mid air"),
# ("A large long train on a steel track.", "A large long tunnel on a steel track."),
# ("A large long tunnel on a steel track.", "A large long train on a steel track."),
# ("A large table with many vases of flowers.", "A large garden with many vases of flowers."),
# ("A large garden with many vases of flowers.", "A large table with many vases of flowers."),
# ("An outdoor cage with tall, thin colorful birds.", "An outdoor patio with tall, thin colorful birds."),
# ("An outdoor patio with tall, thin colorful birds.", "An outdoor cage with tall, thin colorful birds."),
# 474
# ("A man holding a square shaped pizza pie.", "A man holding a pumpkin shaped pizza pie."),
# ("A man holding a pumpkin shaped pizza pie.", "A man holding a square shaped pizza pie."),
# ("A white sink sitting next to a toilet.", "A white elephant sitting next to a toilet."),
# ("A white elephant sitting next to a toilet.", "A white sink sitting next to a toilet."),
# ("A red fire truck driving down a  street.", "A red pickup truck driving down a  street."),
# ("A red pickup truck driving down a  street.", "A red fire truck driving down a  street."),
# ("a vase with some flowers near a window", "a tree with some flowers near a window"),
# ("a tree with some flowers near a window", "a vase with some flowers near a window"),
# ("A Honda motorcycle parked in a grass driveway", "A Honda Civic parked in a grass driveway"),
# ("A Honda Civic parked in a grass driveway", "A Honda motorcycle parked in a grass driveway"),
# 479
# ("a pizza next to a glass of beer ", "a spoon next to a glass of beer "),
# ("a spoon next to a glass of beer ", "a pizza next to a glass of beer "),
# ("A girl getting pushed in a child's swing.", "A girl getting pushed in a child's bathroom."),
# ("A girl getting pushed in a child's bathroom.", "A girl getting pushed in a child's swing."),
# ("a young female wearing shorts on a skateboard", "a young boy wearing shorts on a skateboard"),
# ("a young boy wearing shorts on a skateboard", "a young female wearing shorts on a skateboard"),
# ("Many umbrellas shade the beach from the sun.", "Many umbrellas shade the city from the sun."),
# ("Many umbrellas shade the city from the sun.", "Many umbrellas shade the beach from the sun."),
# ("A bowl contains baby carrots and other food.", "A jar contains baby carrots and other food."),
# ("A jar contains baby carrots and other food.", "A bowl contains baby carrots and other food."),
# 484
# ("two medical professionals inside of an hospital. ", "two medical professionals inside of an ambulance. "),
# ("two medical professionals inside of an ambulance. ", "two medical professionals inside of an hospital. "),
# ("a collage of photos with many electronics ", "a collection of photos with many electronics "),
# ("a collection of photos with many electronics ", "a collage of photos with many electronics "),
# ("Two small planes are parked on the tarmac.", "Two small planes are parked on the runway."),
# ("Two small planes are parked on the runway.", "Two small planes are parked on the tarmac."),
# ("A harbor filled with boats floating on water.", "A lake filled with boats floating on water."),
# ("A lake filled with boats floating on water.", "A harbor filled with boats floating on water."),
# ("A display of clocks inside a shop window.", "A stack of clocks inside a shop window."),
# ("A stack of clocks inside a shop window.", "A display of clocks inside a shop window."),
# 489
# ("a small dog is standing in a sink", "a small fish is standing in a sink"),
# ("a small fish is standing in a sink", "a small dog is standing in a sink"),
# ("A large  clock mounted on a tower ", "A large antenna mounted on a tower "),
# ("A large antenna mounted on a tower ", "A large  clock mounted on a tower "),
# ("A field full of green plants and fruit.", "A garden full of green plants and fruit."),
# ("A garden full of green plants and fruit.", "A field full of green plants and fruit."),
# ("A skateboarder rides along a diagonally slanted wall.", "A train rides along a diagonally slanted wall."),
# ("A train rides along a diagonally slanted wall.", "A skateboarder rides along a diagonally slanted wall."),
# ("Fresh red and yellow tulips in a vase.", "Fresh red and yellow tulips in a basket."),
# ("Fresh red and yellow tulips in a basket.", "Fresh red and yellow tulips in a vase."),
# 494
# ("A healthy plate of guacamole, broccoli, and toast.", "A healthy plate of guacamole, broccoli, and kale."),
# ("A healthy plate of guacamole, broccoli, and kale.", "A healthy plate of guacamole, broccoli, and toast."),
# ("A pot full of beef and broccoli stew. ", "A plate full of beef and broccoli stew. "),
# ("A plate full of beef and broccoli stew. ", "A pot full of beef and broccoli stew. "),
# ("A woman adjusts clock while several people watch.", "A woman adjusts sunglasses while several people watch."),
# ("A woman adjusts sunglasses while several people watch.", "A woman adjusts clock while several people watch."),
# ("There are two kites flying in the wind.", "There are two kites flying in the sky."),
# ("There are two kites flying in the sky.", "There are two kites flying in the wind."),
# ("BASEBALL GAME GOING ON WITH BATTER AT BAT", " BEST GAME GOING ON WITH BATTER AT BAT"),
# (" BEST GAME GOING ON WITH BATTER AT BAT", "BASEBALL GAME GOING ON WITH BATTER AT BAT"),
# 499

# %%
for_csv = {
    "input_text":[],
    "target_text":[]
}

for i, row in df2.iterrows():
    for_csv["input_text"].append(row["base_sentence"])
    for_csv["target_text"].append(row["new_sentence"])

    for_csv["input_text"].append(row["new_sentence"])
    for_csv["target_text"].append(row["base_sentence"])


df3 = pd.DataFrame(for_csv)
df3.to_csv("COCO_test_pairs.csv", index=False)
